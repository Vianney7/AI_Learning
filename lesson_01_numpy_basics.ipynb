# %% [markdown]
# <a href="https://colab.research.google.com/github/Vianney7/AI_Learning/blob/main/lesson_01_numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lesson 1: NumPy = how AI does math
import numpy as np

# Think of this like an Excel row, but for AI
data = np.array([10, 10, 10, 10, 10])
print("Our data:", data)

# AI models love matrix math. This is a "dot product" - super common
weights = np.array([0, 0, 1, 0, 0])
prediction = np.dot(data, weights)

print("Prediction from our tiny 'model':", prediction)
print("Data shape:", data.shape)  # AI people obsess over shapes
print("Sum of data:", np.sum(data))
print("Mean of data:", np.mean(data))
print("Prediction with 0.2 weights:", np.sum(data) * 0.2)
# Out:
# Our data: [10 10 10 10 10]
# Prediction from our tiny 'model': 10
# Data shape: (5,)
# Sum of data: 50
# Mean of data: 10.0
# Prediction with 0.2 weights: 10.0

# %%
# Lesson 2: Pandas — Real Data

import pandas as pd

# Pandas can read data straight from the internet
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

print("First 5 rows:")
print(df.head())

print(df.columns.tolist())
print(len(df['tip']))      # 244
print(df['tip'].shape)     # (244,)
print(df.shape)            # (244, 7)
print(df['tip'].tolist())
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']
# 244
# (244,)
# (244, 7)
# ...

# %%
# Lesson 2: Pandas — Real Data

import pandas as pd

# Pandas can read data straight from the internet
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

print("First 5 rows:")
print(df.head())

print(df.columns.tolist())
print(len(df['tip']))      # 244
print(df['tip'].shape)     # (244,)
print(df.shape)            # (244, 7)
print(df['tip'].tolist())
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']
# 244
# (244,)
# (244, 7)
# ...

# %%
# Lesson 2: Pandas — Real Data

import pandas as pd

# Pandas can read data straight from the internet
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)
total_bill = 16.99
tip = 1.01
tip_percent = tip / total_bill * 100
print(tip_percent)
# Out:
# 5.9446733372572105

# %%
Lesson 2: filter dataframe for big tippers
big_tippers = df[df['tip'] > 5]
print("Number of tips over $5:", len(big_tippers))
print(big_tippers.head())
# Out:
# Number of tips over $5: 18
#     total_bill   tip     sex smoker  day    time  size
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4
# 52       34.81  5.20  Female     No  Sun  Dinner     4
# 59       48.27  6.73    Male     No  Sat  Dinner     4

# %%
big_tippers = df[df['tip'] > 5]
big_tippers['tip_percent'] = big_tippers['tip'] / big_tippers['total_bill'] * 100
print("Average tip % from big tippers:", big_tippers['tip_percent'].mean())
# Out:
# Average tip % from big tippers: 22.348106495608576
# /tmp/ipykernel_2002/865507362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_tippers['tip_percent'] = big_tippers['tip'] / big_tippers['total_bill'] * 100
