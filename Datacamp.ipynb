# %% [markdown]
# <a href="https://colab.research.google.com/github/Vianney7/AI_Learning/blob/main/Datacamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x,y)
plt.show()

# %%
i

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]
plt.yticks([3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7])
plt.plot(year, pop)
plt.show()

# %% [markdown]
# git commit -m "Explored matplotlib auto vs manual y-axis ticks"

# %%
import matplotlib.pyplot as plt
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]
plt.scatter(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.scatter(year, pop)

plt.xlabel("Year")
plt.ylabel("Population (billions)")
plt.title("World Population (Scatter Plot)")

plt.show()

# %% [markdown]
# Additions to the label
