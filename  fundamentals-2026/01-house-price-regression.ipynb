# %% [markdown]
# <a href="https://colab.research.google.com/github/Vianney7/AI_Learning/blob/main/%20fundamentals-2026/01-house-price-regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn
import tensorflow as tf

print("Pandas:", pd.__version__)
print("Sklearn:", sklearn.__version__)
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# Pandas: 2.2.2
# Sklearn: 1.6.1
# TensorFlow: 2.19.0
# GPU: []
