# %%
name = "Vianney"
genre = "Thriller"
show = "WWE"
time = 45
completed = True
print(name + " watched " + show + " (" + genre + ") for " + str(time) + " today and finished: " + str(completed))
# Out:
# Vianney watched WWE (Thriller) for 45 today and finished: True
