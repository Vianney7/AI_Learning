# %%
favorite_genres = ['Syfy', 'action', 'Romance', 'Faith']
print(favorite_genres)
# Out:
# ['Syfy', 'action', 'Romance', 'Faith']

# %%
favorite_genres = ['Syfy', 'action', 'Romance', 'Faith']
print(favorite_genres)
# Out:
# ['Syfy', 'action', 'Romance', 'Faith']

# %%
favorite_genres = ['Syfy', 'action', 'Romance', 'Faith']
print(favorite_genres[0])
# Out:
# Syfy

# %%
name = 'Vianney'
show = 'WWE'
time = 45
completed = True
favorite_genres = ['Syfy', 'action', 'Romance', 'Faith']
print(name + " watched " + show + " (" + favorite_genres[0] + ") for " + str(time) + " today and finished: " + str(completed))
# Out:
# Vianney watched WWE (Syfy) for 45 today and finished: True
